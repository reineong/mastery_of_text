# %%
# Import necessary libraries
import requests
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import random

iss_data = []

# Use the generated timestamps
timestamps_unix = [
    1719990242, 1719990252, 1719990262, 1719990272, 1719990282,
    1719990292, 1719990302, 1719990312, 1719990322, 1719990332,
    1719990342, 1719990352, 1719990362, 1719990372, 1719990382,
    1719990392, 1719990402, 1719990412, 1719990422, 1719990432,
    1719990442, 1719990452, 1719990462, 1719990472, 1719990482,
    1719990492, 1719990502, 1719990512, 1719990522, 1719990532,
    1719990542, 1719990552, 1719990562, 1719990572, 1719990582,
    1719990592, 1719990602, 1719990612, 1719990622, 1719990632,
    1719990642, 1719990652, 1719990662, 1719990672, 1719990682,
    1719990692, 1719990702, 1719990712, 1719990722, 1719990732,
    1719990742, 1719990752, 1719990762, 1719990772, 1719990782,
    1719990792, 1719990802, 1719990812, 1719990822, 1719990832,
    1719990842, 1719990852, 1719990862, 1719990872, 1719990882,
    1719990892, 1719990902, 1719990912, 1719990922, 1719990932,
    1719990942, 1719990952, 1719990962, 1719990972, 1719990982,
    1719990992, 1719991002, 1719991012, 1719991022, 1719991032,
    1719991042, 1719991052, 1719991062, 1719991072, 1719991082,
    1719991092, 1719991102, 1719991112, 1719991122, 1719991132,
    1719991142, 1719991152, 1719991162, 1719991172, 1719991182,
    1719991192, 1719991202, 1719991212, 1719991222, 1719991232
]

# Simulate data collection using the generated timestamps
for timestamp in timestamps_unix:
    # Simulate fetching data
    latitude = random.uniform(-90, 90)
    longitude = random.uniform(-180, 180)
    iss_data.append((timestamp, latitude, longitude))

# Data Visualization
timestamps, latitudes, longitudes = zip(*iss_data)
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(longitudes, latitudes, color='pink', marker='o', linestyle='-')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Simulated ISS Path')
ax.grid(True)

plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import numpy as np

# Step 1: Generate Timestamps
start_time = datetime.utcnow()
timestamps = [start_time + timedelta(seconds=10*i) for i in range(100)]
timestamps_unix = [int(timestamp.timestamp()) for timestamp in timestamps]

# Step 2: Generate Realistic Latitudes and Longitudes
# For realism, let's simulate a smooth path for the ISS.
# The ISS orbits approximately every 90 minutes, so let's simulate part of an orbit.

# Generate 100 latitude values varying smoothly between -51.6 and 51.6 degrees (typical ISS orbit inclination)
latitudes = np.linspace(-51.6, 51.6, 100)

# Generate 100 longitude values wrapping around from -180 to 180 degrees
longitudes = np.linspace(-180, 180, 100)

# Smooth variation with sine wave to simulate realistic movement
latitudes = 51.6 * np.sin(np.linspace(0, 2 * np.pi, 100))
longitudes = 180 * np.sin(np.linspace(0, 4 * np.pi, 100))

# Combine the data points
iss_data = list(zip(timestamps_unix, latitudes, longitudes))

# Step 3: Data Visualization
timestamps, latitudes, longitudes = zip(*iss_data)
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(longitudes, latitudes, color='blue', marker='o', linestyle='-')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Simulated ISS Path Over Time')
ax.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import numpy as np

# Generate 100 timestamps in 10-second increments starting from now
start_time = datetime.utcnow()
timestamps = [start_time + timedelta(seconds=10 * i) for i in range(100)]
timestamps_unix = [int(timestamp.timestamp()) for timestamp in timestamps]

# Generate realistic latitudes and longitudes for a curved path
# For a smooth, curved path, let's simulate a segment of an orbit

# Latitude: Varies between -51.6 and 51.6 degrees
latitudes = 51.6 * np.sin(np.linspace(0, 2 * np.pi, 100))

# Longitude: Simulate continuous movement across the globe, from -180 to 180 degrees
longitudes = 180 * np.sin(np.linspace(0, 4 * np.pi, 100))

# Combine the generated data points
iss_data = list(zip(timestamps_unix, latitudes, longitudes))

# Data Visualization
timestamps, latitudes, longitudes = zip(*iss_data)
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(longitudes, latitudes, color='blue', marker='o', linestyle='-')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Simulated ISS Path Over Time')
ax.grid(True)

plt.show()

# %%
# Import necessary libraries
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import numpy as np

# Step 1: Generate Timestamps
start_time = datetime.utcnow()
timestamps = [start_time + timedelta(seconds=10 * i) for i in range(100)]
timestamps_unix = [int(timestamp.timestamp()) for timestamp in timestamps]

# Step 2: Generate Latitudes and Longitudes for an upward curve (half of a U shape)
# Latitude varies between -51.6 and 51.6 degrees, forming a half U shape
latitudes = 51.6 * np.sin(np.linspace(0, np.pi, 100))

# Longitude starts at -180 and goes to 180 degrees in a U shape
longitudes = np.linspace(-180, 180, 100)

# Combine the generated data points
iss_data = list(zip(timestamps_unix, latitudes, longitudes))

# Data Visualization
timestamps, latitudes, longitudes = zip(*iss_data)
fig, ax = plt.subplots(figsize=(12, 8))

ax.plot(longitudes, latitudes, color='blue', marker='o', linestyle='-')

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_title('Simulated ISS Path (Upward Curve)')
ax.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import requests

latitude = []
longitude = []
timestamp_data = ['1728018000', '1728018000', '1728018010', '1728018020', '1728018030', '1728018040', '1728018050', '1728018060', '1728018070', '1728018080', '1728018090', '1728018100', '1728018110', '1728018120', '1728018130', '1728018140', '1728018150', '1728018160', '1728018170', '1728018180', '1728018190', '1728018200', '1728018210', '1728018220', '1728018230', '1728018240', '1728018250', '1728018260', '1728018270', '1728018280', '1728018290', '1728018300', '1728018310', '1728018320', '1728018330', '1728018340', '1728018350', '1728018360', '1728018370', '1728018380', '1728018390', '1728018400', '1728018410', '1728018420', '1728018430', '1728018440', '1728018450', '1728018460', '1728018470', '1728018480', '1728018490', '1728018500', '1728018510', '1728018520', '1728018530', '1728018540', '1728018550', '1728018560', '1728018570', '1728018580', '1728018590', '1728018600', '1728018610', '1728018620', '1728018630', '1728018640', '1728018650', '1728018660', '1728018670', '1728018680', '1728018690', '1728018700', '1728018710', '1728018720', '1728018730', '1728018740', '1728018750', '1728018760', '1728018770', '1728018780', '1728018790', '1728018800', '1728018810', '1728018820', '1728018830', '1728018840', '1728018850', '1728018860', '1728018870', '1728018880', '1728018890', '1728018900', '1728018910', '1728018920', '1728018930', '1728018940', '1728018950', '1728018960', '1728018970', '1728018980', '1728018990']

for specific_time in timestamp_data:
    url = "https://api.wheretheiss.at/v1/satellites/25544"
    html = requests.get(url, params = {'timestamp':specific_time})
    html_data = html.json()
    latitude.append(html_data['latitude'])
    longitude.append(html_data['longitude'])

fig, ax = plt.subplots()

ax.scatter(latitude, longitude)
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_title('ISS Location')

plt.show()
